# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
from PyLyrics import *
import re

# %%
# import list of albums and decade

df = pd.read_csv('albums_2.csv')
df.head()
# Out:
#    decade                   album
# 0      80  1cvyT4p26JXJicEBbHPzvX
# 1      80  57LWYtFS2xn5pIDHLqjatU
# 2      80  3vuQ0qc1DF5jJ4mz5Thm5J
# 3      80  54kAN7Lrdwt8j8EX70RITl
# 4      80  5opAMGIf8Hn7xIaTPdHFDv

# %%
# get each track in each album

track = pd.DataFrame(columns = ['id_', 'name', 'artist_id', 'artist', 'decade'])
count = 0
for i in df['album']:

    endpoint = "https://api.spotify.com/v1/albums/"+i+"/tracks"
    headers = {"Authorization":"Bearer BQAjMC0i6a99ZrTeToBR6fun6_yYjT0Vr29POqTubHnsZ-73yZ1B_LqD62bNbhwGcXGW9hKQjT9_Kl_C-E8"}

    data = requests.get(endpoint,headers=headers).json()
    table = json_normalize(data, 'items')
    
    id_ = []
    name = []
    artist = []
    artist_id = []
    decade = []
    for n in np.arange(len(table)):   
        id_.append(table.iloc[n, 7])
        name.append(table.iloc[n, 8])
        artist.append(table.iloc[n, 0][0]['name'])
        artist_id.append(table.iloc[n, 0][0]['id'])
        decade.append(df.decade[count])
    
    table2 = pd.DataFrame()
    table2['id_'] = id_
    table2['name'] = name
    table2['artist_id'] = artist_id
    table2['artist'] = artist
    table2['decade'] = decade
    track = pd.concat([track, table2], axis=0)
    count = count + 1

track.head()
# Out:
#                       id_                     name               artist_id  \
# 0  5umqT5PCkHhwfRSaw0zaMw   It's A Big Daddy Thing  6futYSDVulYR2PktBjTB5W
# 1  1iQZ8TG5knmq01wtbc2KWz          Another Victory  6futYSDVulYR2PktBjTB5W
# 2  3PMJeC601827YaF2MCKiGt            Mortal Combat  6futYSDVulYR2PktBjTB5W
# 3  5VJykDnMgX9e3b6AreIFmx    Children R The Future  6futYSDVulYR2PktBjTB5W
# 4  0cUdIgxc8bvI7VF7UtOe1t  Young, Gifted And Black  6futYSDVulYR2PktBjTB5W
#
#            artist decade
# 0  Big Daddy Kane     80
# 1  Big Daddy Kane     80
# 2  Big Daddy Kane     80
# 3  Big Daddy Kane     80
# 4  Big Daddy Kane     80

# %%
# get lyrics

lr = []
for i in np.arange(len(track)):
    try: 
        lyrics = PyLyrics.getLyrics(track.iloc[i, 3],track.iloc[i, 1])
        lr.append(lyrics)
    except Exception:
        lr.append('none')
        
track['lyrics'] = lr
track.head()
# Out:
# /Users/litalert/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/litalert/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#                       id_                     name               artist_id  \
# 0  5umqT5PCkHhwfRSaw0zaMw   It's A Big Daddy Thing  6futYSDVulYR2PktBjTB5W
# 1  1iQZ8TG5knmq01wtbc2KWz          Another Victory  6futYSDVulYR2PktBjTB5W
# 2  3PMJeC601827YaF2MCKiGt            Mortal Combat  6futYSDVulYR2PktBjTB5W
# 3  5VJykDnMgX9e3b6AreIFmx    Children R The Future  6futYSDVulYR2PktBjTB5W
# 4  0cUdIgxc8bvI7VF7UtOe1t  Young, Gifted And Black  6futYSDVulYR2PktBjTB5W
#
#            artist decade                                             lyrics
# 0  Big Daddy Kane     80  Ah yeah\nWe gon' pump this up one time\nAs we ...
# 1  Big Daddy Kane     80  Here comes the conquering brother that fathoms...
# 2  Big Daddy Kane     80  The kiss of death on a rap pick\nThen you get ...
# 3  Big Daddy Kane     80  On and on and on and on\nMe say the beat don't...
# 4  Big Daddy Kane     80  (Minister Farrakhan)\nSo out of the MERCY of A...

# %%
# label 

label = []
for i in track.decade:
    if i==80:
        label.append(1)
    if i==90:
        label.append(2)
    if i==2000:
        label.append(3)
        
track['label'] = label
track.head()
# Out:
#                       id_                     name               artist_id  \
# 0  5umqT5PCkHhwfRSaw0zaMw   It's A Big Daddy Thing  6futYSDVulYR2PktBjTB5W
# 1  1iQZ8TG5knmq01wtbc2KWz          Another Victory  6futYSDVulYR2PktBjTB5W
# 2  3PMJeC601827YaF2MCKiGt            Mortal Combat  6futYSDVulYR2PktBjTB5W
# 3  5VJykDnMgX9e3b6AreIFmx    Children R The Future  6futYSDVulYR2PktBjTB5W
# 4  0cUdIgxc8bvI7VF7UtOe1t  Young, Gifted And Black  6futYSDVulYR2PktBjTB5W
#
#            artist decade                                             lyrics  \
# 0  Big Daddy Kane     80  Ah yeah\nWe gon' pump this up one time\nAs we ...
# 1  Big Daddy Kane     80  Here comes the conquering brother that fathoms...
# 2  Big Daddy Kane     80  The kiss of death on a rap pick\nThen you get ...
# 3  Big Daddy Kane     80  On and on and on and on\nMe say the beat don't...
# 4  Big Daddy Kane     80  (Minister Farrakhan)\nSo out of the MERCY of A...
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# get rid of songs w/o lyrics

track_ = track[track['lyrics'] != 'none']

has_lyrics = []
for i in np.arange(len(track_.lyrics)):
    if '<span' in track_.iloc[i][5]:
        has_lyrics.append(False)
    else:
        has_lyrics.append(True)

track_ = track_[has_lyrics]
track_.to_csv('track_decade_2.csv')
track_.head()
# Out:
#                       id_                     name               artist_id  \
# 0  5umqT5PCkHhwfRSaw0zaMw   It's A Big Daddy Thing  6futYSDVulYR2PktBjTB5W
# 1  1iQZ8TG5knmq01wtbc2KWz          Another Victory  6futYSDVulYR2PktBjTB5W
# 2  3PMJeC601827YaF2MCKiGt            Mortal Combat  6futYSDVulYR2PktBjTB5W
# 3  5VJykDnMgX9e3b6AreIFmx    Children R The Future  6futYSDVulYR2PktBjTB5W
# 4  0cUdIgxc8bvI7VF7UtOe1t  Young, Gifted And Black  6futYSDVulYR2PktBjTB5W
#
#            artist decade                                             lyrics  \
# 0  Big Daddy Kane     80  Ah yeah\nWe gon' pump this up one time\nAs we ...
# 1  Big Daddy Kane     80  Here comes the conquering brother that fathoms...
# 2  Big Daddy Kane     80  The kiss of death on a rap pick\nThen you get ...
# 3  Big Daddy Kane     80  On and on and on and on\nMe say the beat don't...
# 4  Big Daddy Kane     80  (Minister Farrakhan)\nSo out of the MERCY of A...
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# making a corpus and cleaning 

corpus = track_.drop(['id_', 'name', 'artist_id', 'artist', 'decade'], 1)

corpus['lyrics'] = [song.lower() for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace(',','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace('.','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace(';','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace('(','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace(')','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace('!','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace('"','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace('*','') for song in corpus['lyrics']]
corpus['lyrics'] = [song.replace(':','') for song in corpus['lyrics']]

corpus.to_csv('corpus_decade_2.csv')
corpus.head()
# Out:
#                                               lyrics  label
# 0  ah yeah\nwe gon' pump this up one time\nas we ...      1
# 1  here comes the conquering brother that fathoms...      1
# 2  the kiss of death on a rap pick\nthen you get ...      1
# 3  on and on and on and on\nme say the beat don't...      1
# 4  minister farrakhan\nso out of the mercy of all...      1
